# %%
import pandas as pd
import numpy as np

# %%
df_raw = pd.read_csv("junqich_zhaoss_si618_hw7_batch_result.csv")
df = df_raw[["Input.comment_text", "Answer.target1.yes", "Answer.target2.no", "Answer.target3.na", "Answer.toxic1.yes", "Answer.toxic2.no"]]
df.head()
# Out:
#                                   Input.comment_text  Answer.target1.yes  \
# 0  So let me get this straight. We are going to s...               False
# 1  So let me get this straight. We are going to s...                True
# 2  So let me get this straight. We are going to s...               False
# 3                        Shoot to kill or be killed.                True
# 4                        Shoot to kill or be killed.               False
#
#    Answer.target2.no  Answer.target3.na  Answer.toxic1.yes  Answer.toxic2.no
# 0              False               True              False              True
# 1              False              False              False              True
# 2              False               True              False              True
# 3              False              False               True             False
# 4               True              False               True             False

# %%
# compute the fraction of comments that were labeled as toxic
df_group = df.groupby("Input.comment_text").sum()
toxic_1 = len(df_group[df_group["Answer.toxic1.yes"] >= 1]) / len(df_group) # at least once
toxic_2 = len(df_group[df_group["Answer.toxic1.yes"] >= 2]) / len(df_group) # at least 2
toxic_3 = len(df_group[df_group["Answer.toxic1.yes"] >= 3]) / len(df_group) # at least 3

# %%
# compute the fraction of toxic comments that are also labeled as targeted at least once
df_toxic = df_group[df_group["Answer.toxic1.yes"] >= 2]
targeted = len(df_toxic[df_toxic["Answer.target1.yes"] >= 1]) / len(df_toxic)

# %%
# save to txt file
with open("junqich_zhaoss_si618_hw7_batch_result.txt", "w") as file:
    file.write(f"toxic_1\t{toxic_1}\n")
    file.write(f"toxic_2\t{toxic_2}\n")
    file.write(f"toxic_3\t{toxic_3}\n")
    file.write(f"targeted\t{targeted}\n")

# %%
df_toxic = df_group[df_group["Answer.toxic1.yes"] >= 2]
df_toxic
# Out:
#                                                     Answer.target1.yes  \
# Input.comment_text
# .\n"People should assume NHL will not send play...                   2
# Anyone who allows Obama to nominate him/her is ...                   1
# Because, because, children! That's the ticket! ...                   2
# Can we just say it already? The Pacific islande...                   3
# Dougie's another one on the endless growth band...                   2
# Get them to put a nuke in the next one and bake...                   2
# I guess Sen. Maria Chappell-Nadal will have to ...                   3
# I know.  I wanted to be an astronaut when I was...                   2
# Jail would be good for this buffoon.                                 2
# No, we're not going to let psychos and the depr...                   2
# OMG, The Used To Be Daily Garbage is doing ever...                   2
# Paranoia strikes deep.                                               2
# Retiree:  You really need a hobby because you a...                   1
# See if you can come up with something even more...                   1
# Shoot to kill or be killed.                                          1
# So much better to vote republican?   Hell, repu...                   2
# That's not true. Cayetano has opposed every for...                   2
# This is good news as I can hardly wait until JT...                   2
# This is the moment when my liberal instincts cr...                   3
# This issue will go away the moment we stop the ...                   2
# Typical. Like a kid caught red-handed with thei...                   2
# What a silly comment. Canada IS a peaceful plac...                   3
# What an unfortunate ad hominem attack by Nicole...                   3
# o'Gwede is the biggest snake in the corrupt ANC...                   3
#
#                                                     Answer.target2.no  \
# Input.comment_text
# .\n"People should assume NHL will not send play...                  0
# Anyone who allows Obama to nominate him/her is ...                  1
# Because, because, children! That's the ticket! ...                  0
# Can we just say it already? The Pacific islande...                  0
# Dougie's another one on the endless growth band...                  0
# Get them to put a nuke in the next one and bake...                  1
# I guess Sen. Maria Chappell-Nadal will have to ...                  0
# I know.  I wanted to be an astronaut when I was...                  0
# Jail would be good for this buffoon.                                1
# No, we're not going to let psychos and the depr...                  0
# OMG, The Used To Be Daily Garbage is doing ever...                  1
# Paranoia strikes deep.                                              0
# Retiree:  You really need a hobby because you a...                  1
# See if you can come up with something even more...                  2
# Shoot to kill or be killed.                                         2
# So much better to vote republican?   Hell, repu...                  0
# That's not true. Cayetano has opposed every for...                  0
# This is good news as I can hardly wait until JT...                  0
# This is the moment when my liberal instincts cr...                  0
# This issue will go away the moment we stop the ...                  0
# Typical. Like a kid caught red-handed with thei...                  0
# What a silly comment. Canada IS a peaceful plac...                  0
# What an unfortunate ad hominem attack by Nicole...                  0
# o'Gwede is the biggest snake in the corrupt ANC...                  0
#
#                                                     Answer.target3.na  \
# Input.comment_text
# .\n"People should assume NHL will not send play...                  1
# Anyone who allows Obama to nominate him/her is ...                  1
# Because, because, children! That's the ticket! ...                  1
# Can we just say it already? The Pacific islande...                  0
# Dougie's another one on the endless growth band...                  1
# Get them to put a nuke in the next one and bake...                  0
# I guess Sen. Maria Chappell-Nadal will have to ...                  0
# I know.  I wanted to be an astronaut when I was...                  1
# Jail would be good for this buffoon.                                0
# No, we're not going to let psychos and the depr...                  1
# OMG, The Used To Be Daily Garbage is doing ever...                  0
# Paranoia strikes deep.                                              1
# Retiree:  You really need a hobby because you a...                  1
# See if you can come up with something even more...                  0
# Shoot to kill or be killed.                                         0
# So much better to vote republican?   Hell, repu...                  1
# That's not true. Cayetano has opposed every for...                  1
# This is good news as I can hardly wait until JT...                  1
# This is the moment when my liberal instincts cr...                  0
# This issue will go away the moment we stop the ...                  1
# Typical. Like a kid caught red-handed with thei...                  1
# What a silly comment. Canada IS a peaceful plac...                  0
# What an unfortunate ad hominem attack by Nicole...                  0
# o'Gwede is the biggest snake in the corrupt ANC...                  0
#
#                                                     Answer.toxic1.yes  \
# Input.comment_text
# .\n"People should assume NHL will not send play...                  2
# Anyone who allows Obama to nominate him/her is ...                  2
# Because, because, children! That's the ticket! ...                  2
# Can we just say it already? The Pacific islande...                  3
# Dougie's another one on the endless growth band...                  2
# Get them to put a nuke in the next one and bake...                  3
# I guess Sen. Maria Chappell-Nadal will have to ...                  2
# I know.  I wanted to be an astronaut when I was...                  2
# Jail would be good for this buffoon.                                2
# No, we're not going to let psychos and the depr...                  2
# OMG, The Used To Be Daily Garbage is doing ever...                  2
# Paranoia strikes deep.                                              2
# Retiree:  You really need a hobby because you a...                  2
# See if you can come up with something even more...                  2
# Shoot to kill or be killed.                                         3
# So much better to vote republican?   Hell, repu...                  2
# That's not true. Cayetano has opposed every for...                  2
# This is good news as I can hardly wait until JT...                  2
# This is the moment when my liberal instincts cr...                  3
# This issue will go away the moment we stop the ...                  2
# Typical. Like a kid caught red-handed with thei...                  2
# What a silly comment. Canada IS a peaceful plac...                  2
# What an unfortunate ad hominem attack by Nicole...                  3
# o'Gwede is the biggest snake in the corrupt ANC...                  3
#
#                                                     Answer.toxic2.no
# Input.comment_text
# .\n"People should assume NHL will not send play...                 1
# Anyone who allows Obama to nominate him/her is ...                 1
# Because, because, children! That's the ticket! ...                 1
# Can we just say it already? The Pacific islande...                 0
# Dougie's another one on the endless growth band...                 1
# Get them to put a nuke in the next one and bake...                 0
# I guess Sen. Maria Chappell-Nadal will have to ...                 1
# I know.  I wanted to be an astronaut when I was...                 1
# Jail would be good for this buffoon.                               1
# No, we're not going to let psychos and the depr...                 1
# OMG, The Used To Be Daily Garbage is doing ever...                 1
# Paranoia strikes deep.                                             1
# Retiree:  You really need a hobby because you a...                 1
# See if you can come up with something even more...                 1
# Shoot to kill or be killed.                                        0
# So much better to vote republican?   Hell, repu...                 1
# That's not true. Cayetano has opposed every for...                 1
# This is good news as I can hardly wait until JT...                 1
# This is the moment when my liberal instincts cr...                 0
# This issue will go away the moment we stop the ...                 1
# Typical. Like a kid caught red-handed with thei...                 1
# What a silly comment. Canada IS a peaceful plac...                 1
# What an unfortunate ad hominem attack by Nicole...                 0
# o'Gwede is the biggest snake in the corrupt ANC...                 0
